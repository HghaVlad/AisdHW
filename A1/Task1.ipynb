# %%
import pandas as pd

# %%
df = pd.read_csv("results.csv")

# %%
df
# Out:
#          N  wide_area  narrow_area  wide_error  narrow_error
# 0      100  30.077722    25.934919   29.077722     24.934919
# 1      600  23.059587    23.582173   22.059587     22.582173
# 2     1100  23.788744    23.159375   22.788744     22.159375
# 3     1600  22.840270    23.164971   21.840270     22.164971
# 4     2100  21.913769    23.167902   20.913769     22.167902
# ..     ...        ...          ...         ...           ...
# 195  97600  23.240896    22.964835   22.240896     21.964835
# 196  98100  23.220553    22.970268   22.220553     21.970268
# 197  98600  23.241599    22.969653   22.241599     21.969653
# 198  99100  23.236634    22.963413   22.236634     21.963413
# 199  99600  23.231719    22.963498   22.231719     21.963498
#
# [200 rows x 5 columns]

# %%
df.plot(x='N',
          y=['wide_area', 'narrow_area', 'wide_error', 'narrow_error'],
          subplots=True,
          layout=(2, 2),
          figsize=(15, 10),
          title=['Широкая область', 'Узкая область', 'Отклонение широкой области', 'Отклонение узкой области'])
# Out:
# array([[<Axes: title={'center': 'Широкая область'}, xlabel='N'>,
#         <Axes: title={'center': 'Узкая область'}, xlabel='N'>],
#        [<Axes: title={'center': 'Отклонение широкой области'}, xlabel='N'>,
#         <Axes: title={'center': 'Отклонение узкой области'}, xlabel='N'>]],
#       dtype=object)
